# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
import math
data= pd.read_csv('D:tested.csv')

data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
print("Number of movies in the original list: " +str(len(data.index)))
# Out:
# Number of movies in the original list: 418

# %% [markdown]
# # Analyzing Data

# %%
sns.countplot(x="Survived", data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Age", data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="seasons", data=data)
# Out:
# <Axes: xlabel='seasons', ylabel='count'>

# %%
sns.countplot(x="Survived",hue="Sex", data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",hue="Pclass", data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
data["Age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data["Fare"].plot.hist(bins=20 ,figsize=(10, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([0,1,2,3])
y= np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)

x= np.array([0,1,2,3])
y= np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x= np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y= np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

x= np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y= np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])


plt.scatter(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt\

x= np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y= np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)


x= np.array([2,2,8,1,15,12,9,7,3,11,4,7,14,12])
y= np.array([100,105,84,84,105,90,99,90,95,94,94,100,79,112,91,80,55])


plt.scatter(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 13
#       9 x= np.array([2,2,8,1,15,12,9,7,3,11,4,7,14,12])
#      10 y= np.array([100,105,84,84,105,90,99,90,95,94,94,100,79,112,91,80,55])
# ---> 13 plt.scatter(x, y)
#      14 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...

# %%
sns.countplot(x="SibSp",data=data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.countplot(x="SibSp",data=data)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # Data wrangling

# %%
data.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data.isnull()
#
# NameError: name 'data' is not defined

# %%
print("Number of movies in the original list: " +str(len(data.index)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print("Number of movies in the original list: " +str(len(data.index)))
#
# NameError: name 'data' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
import math
data= pd.read_csv('D:tested.csv')

data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
data.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data.isnull()
#
# NameError: name 'data' is not defined

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sns.heatmap(data.isnull(), yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %%
sns.boxplot(x="Pclass", y="Age", data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
data.drop("Cabin", axis=1, inplace=True)

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
sns.heatmap(data.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
data.dropna( inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Embarked
# 0  34.5      0      0  330911  7.8292        Q
# 1  47.0      1      0  363272  7.0000        S

# %%
pd.get_dummies(data["Sex"])
# Out:
#      female   male
# 0     False   True
# 1      True  False
# 2     False   True
# 3     False   True
# 4      True  False
# ..      ...    ...
# 409    True  False
# 411    True  False
# 412    True  False
# 414    True  False
# 415   False   True
#
# [331 rows x 2 columns]

# %%
sex =pd.get_dummies(data["Sex"], drop_first=True)
sex.head(5)
# Out:
#     male
# 0   True
# 1  False
# 2   True
# 3   True
# 4  False

# %%
embark = pd.get_dummies(data["Embarked"])
embark.head(5)
# Out:
#        C      Q      S
# 0  False   True  False
# 1  False  False   True
# 2  False   True  False
# 3  False  False   True
# 4  False  False   True

# %%
embark = pd.get_dummies(data["Embarked"], drop_first=True)
embark.head(5)
# Out:
#        Q      S
# 0   True  False
# 1  False   True
# 2   True  False
# 3  False   True
# 4  False   True

# %%
Pc=pd.get_dummies(data["Pclass"])
Pc.head(5)
# Out:
#        1      2      3
# 0  False  False   True
# 1  False  False   True
# 2  False   True  False
# 3  False  False   True
# 4  False  False   True

# %%
Pc = pd.get_dummies(data["Embarked"], drop_first=True)
Pc.head(5)
# Out:
#        Q      S
# 0   True  False
# 1  False   True
# 2   True  False
# 3  False   True
# 4  False   True

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array([10,18,22,30])
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array([10,18,32,40])
myexplodes = [0.2,0,0,0]
mylabels = (["Arts","Science","Math","Machine learning"])
plt.pie(y, labels= mylabels, explode = myexplodes)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array(["A","B","C","D"])

y= np.array([10,18,22,30])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array(["A","B","C","D"])

y= np.array([10,18,22,30])
plt.barh(x,y)
plt.show()

# %% [markdown]
# ## Data wrangling

# %%
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data.head(5)
#
# NameError: name 'data' is not defined

# %%
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data.head(10)
#
# NameError: name 'data' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
import math
data= pd.read_csv('D:tested.csv')

data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
Pc=pd.get_dummies(data["Pclass"])
Pc.head(5)
# Out:
#        1      2      3
# 0  False  False   True
# 1  False  False   True
# 2  False   True  False
# 3  False  False   True
# 4  False  False   True

# %%
Pc=pd.get_dummies(data["Pclass"], drop_first=True)
Pc.head(5)
# Out:
#        2      3
# 0  False   True
# 1  False   True
# 2   True  False
# 3  False   True
# 4  False   True

# %%
embark=pd.get_dummies(data["Embarked"])
embark.head(5)
# Out:
#        C      Q      S
# 0  False   True  False
# 1  False  False   True
# 2  False   True  False
# 3  False  False   True
# 4  False  False   True

# %%
embark = pd.get_dummies(data["Embarked"], drop_first=True)
embark.head(5)
# Out:
#        Q      S
# 0   True  False
# 1  False   True
# 2   True  False
# 3  False   True
# 4  False   True

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.drop("Cabin", axis=1, inplace=True)

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
data.dropna(inplace=True)

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
data.isnull(). sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
sex=pd.get_dummies(data["Sex"])
sex.head(5)
# Out:
#        0      1
# 0  False   True
# 1   True  False
# 2  False   True
# 3  False   True
# 4   True  False

# %%
data["Sex"] = data["Sex"].replace({"female":0, "male":1})

# %%
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 409         1301         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                                   Kelly, Mr. James    1  34.5      0      0
# 1                   Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                          Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                   Wirz, Mr. Albert    1  27.0      0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# ...

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    1  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                              Wirz, Mr. Albert    1  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
pd.get_dummies(data["Sex"])
# Out:
#          0      1
# 0    False   True
# 1     True  False
# 2    False   True
# 3    False   True
# 4     True  False
# ..     ...    ...
# 409   True  False
# 411   True  False
# 412   True  False
# 414   True  False
# 415  False   True
#
# [331 rows x 2 columns]

# %%
data= pd.concat([data,sex,embark,Pc], axis=1)

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0       0.0     3.0
# 1        893.0       1.0     3.0
# 2        894.0       0.0     2.0
# 3        895.0       0.0     3.0
# 4        896.0       1.0     3.0
# 5        897.0       0.0     3.0
# 6        898.0       1.0     3.0
# 7        899.0       0.0     2.0
# 8        900.0       1.0     3.0
# 9        901.0       0.0     3.0
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James  1.0  34.5    0.0    0.0
# 1              Wilkes, Mrs. James (Ellen Needs)  0.0  47.0    1.0    0.0
# 2                     Myles, Mr. Thomas Francis  1.0  62.0    0.0    0.0
# 3                              Wirz, Mr. Albert  1.0  27.0    0.0    0.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  0.0  22.0    1.0    1.0
# 5                    Svensson, Mr. Johan Cervin  1.0  14.0    0.0    0.0
# 6                          Connolly, Miss. Kate  0.0  30.0    0.0    0.0
# ...

# %%
data["Sex"] = data["Sex"].replace({'0':female, '1':male})

# %%
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0          892.0       0.0     3.0
# 1          893.0       1.0     3.0
# 2          894.0       0.0     2.0
# 3          895.0       0.0     3.0
# 4          896.0       1.0     3.0
# ..           ...       ...     ...
# 408          NaN       NaN     NaN
# 410          NaN       NaN     NaN
# 413          NaN       NaN     NaN
# 416          NaN       NaN     NaN
# 417          NaN       NaN     NaN
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5    0.0    0.0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                       Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                                Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# ...

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0       0.0     3.0
# 1        893.0       1.0     3.0
# 2        894.0       0.0     2.0
# 3        895.0       0.0     3.0
# 4        896.0       1.0     3.0
# 5        897.0       0.0     3.0
# 6        898.0       1.0     3.0
# 7        899.0       0.0     2.0
# 8        900.0       1.0     3.0
# 9        901.0       0.0     3.0
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5    0.0    0.0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                     Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                              Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# 5                    Svensson, Mr. Johan Cervin    male  14.0    0.0    0.0
# ...

# %%
data["Sex"] = data["Sex"].replace({'0':"female", '1':"male"})

# %%
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0          892.0       0.0     3.0
# 1          893.0       1.0     3.0
# 2          894.0       0.0     2.0
# 3          895.0       0.0     3.0
# 4          896.0       1.0     3.0
# ..           ...       ...     ...
# 408          NaN       NaN     NaN
# 410          NaN       NaN     NaN
# 413          NaN       NaN     NaN
# 416          NaN       NaN     NaN
# 417          NaN       NaN     NaN
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5    0.0    0.0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                       Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                                Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# ...

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0       0.0     3.0
# 1        893.0       1.0     3.0
# 2        894.0       0.0     2.0
# 3        895.0       0.0     3.0
# 4        896.0       1.0     3.0
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5    0.0    0.0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                     Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                              Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
#
#     Ticket     Fare Embarked      0      1      Q      S      2      3
# 0   330911   7.8292        Q  False   True   True  False  False   True
# 1   363272   7.0000        S   True  False  False   True  False   True
# 2   240276   9.6875        Q  False   True   True  False   True  False
# ...

# %%
data["Sex"] = data["Sex"].replace({0:"female", 1:"male"})
print(data)
data.head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 0          892.0       0.0     3.0
# 1          893.0       1.0     3.0
# 2          894.0       0.0     2.0
# 3          895.0       0.0     3.0
# 4          896.0       1.0     3.0
# ..           ...       ...     ...
# 408          NaN       NaN     NaN
# 410          NaN       NaN     NaN
# 413          NaN       NaN     NaN
# 416          NaN       NaN     NaN
# 417          NaN       NaN     NaN
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5    0.0    0.0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                       Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                                Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# ...

# %%
data["Sex"] = data["Sex"].replace({'False':0, 'True':1})

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0       0.0     3.0
# 1        893.0       1.0     3.0
# 2        894.0       0.0     2.0
# 3        895.0       0.0     3.0
# 4        896.0       1.0     3.0
# 5        897.0       0.0     3.0
# 6        898.0       1.0     3.0
# 7        899.0       0.0     2.0
# 8        900.0       1.0     3.0
# 9        901.0       0.0     3.0
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5    0.0    0.0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                     Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                              Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# 5                    Svensson, Mr. Johan Cervin    male  14.0    0.0    0.0
# ...

# %%
pd.get_dummies(data["Sex"],drop_first=True)
# Out:
#       male
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# ..     ...
# 408  False
# 410  False
# 413  False
# 416  False
# 417  False
#
# [418 rows x 1 columns]

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0       0.0     3.0
# 1        893.0       1.0     3.0
# 2        894.0       0.0     2.0
# 3        895.0       0.0     3.0
# 4        896.0       1.0     3.0
# 5        897.0       0.0     3.0
# 6        898.0       1.0     3.0
# 7        899.0       0.0     2.0
# 8        900.0       1.0     3.0
# 9        901.0       0.0     3.0
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5    0.0    0.0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                     Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                              Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# 5                    Svensson, Mr. Johan Cervin    male  14.0    0.0    0.0
# ...

# %%
data["Q"] = data["Q"].replace({"False":0, "True":1})

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0       0.0     3.0
# 1        893.0       1.0     3.0
# 2        894.0       0.0     2.0
# 3        895.0       0.0     3.0
# 4        896.0       1.0     3.0
# 5        897.0       0.0     3.0
# 6        898.0       1.0     3.0
# 7        899.0       0.0     2.0
# 8        900.0       1.0     3.0
# 9        901.0       0.0     3.0
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5    0.0    0.0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                     Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                              Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# 5                    Svensson, Mr. Johan Cervin    male  14.0    0.0    0.0
# ...

# %%
data.drop(["PassengerId","Name","Sex","Parch","Ticket","Embarked","Pclass"], axis=1 ,inplace=True)

# %%
data.head(10)
# Out:
#    Survived   Age  SibSp     Fare      0      1      Q      S      2      3
# 0       0.0  34.5    0.0   7.8292  False   True   True  False  False   True
# 1       1.0  47.0    1.0   7.0000   True  False  False   True  False   True
# 2       0.0  62.0    0.0   9.6875  False   True   True  False   True  False
# 3       0.0  27.0    0.0   8.6625  False   True  False   True  False   True
# 4       1.0  22.0    1.0  12.2875   True  False  False   True  False   True
# 5       0.0  14.0    0.0   9.2250  False   True  False   True  False   True
# 6       1.0  30.0    0.0   7.6292   True  False   True  False  False   True
# 7       0.0  26.0    1.0  29.0000  False   True  False   True   True  False
# 8       1.0  18.0    0.0   7.2292   True  False  False  False  False   True
# 9       0.0  21.0    2.0  24.1500  False   True  False   True  False   True

# %%
data.drop("0", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 data.drop("0", axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
data.drop(0, axis=1, inplace=True)

# %%
data.head(10)
# Out:
#    Survived   Age  SibSp     Fare      1      Q      S      2      3
# 0       0.0  34.5    0.0   7.8292   True   True  False  False   True
# 1       1.0  47.0    1.0   7.0000  False  False   True  False   True
# 2       0.0  62.0    0.0   9.6875   True   True  False   True  False
# 3       0.0  27.0    0.0   8.6625   True  False   True  False   True
# 4       1.0  22.0    1.0  12.2875  False  False   True  False   True
# 5       0.0  14.0    0.0   9.2250   True  False   True  False   True
# 6       1.0  30.0    0.0   7.6292  False   True  False  False   True
# 7       0.0  26.0    1.0  29.0000   True  False   True   True  False
# 8       1.0  18.0    0.0   7.2292  False  False  False  False   True
# 9       0.0  21.0    2.0  24.1500   True  False   True  False   True

# %%
data["Q"]= data["Q"].replace({"True":1, "False":0})

# %%
print(data)
# Out:
#      Survived   Age  SibSp     Fare      1      Q      S      2      3
# 0         0.0  34.5    0.0   7.8292   True   True  False  False   True
# 1         1.0  47.0    1.0   7.0000  False  False   True  False   True
# 2         0.0  62.0    0.0   9.6875   True   True  False   True  False
# 3         0.0  27.0    0.0   8.6625   True  False   True  False   True
# 4         1.0  22.0    1.0  12.2875  False  False   True  False   True
# ..        ...   ...    ...      ...    ...    ...    ...    ...    ...
# 408       NaN   NaN    NaN      NaN    NaN   True  False  False   True
# 410       NaN   NaN    NaN      NaN    NaN   True  False  False   True
# 413       NaN   NaN    NaN      NaN    NaN  False   True  False   True
# 416       NaN   NaN    NaN      NaN    NaN  False   True  False   True
# 417       NaN   NaN    NaN      NaN    NaN  False  False  False   True
#
# [418 rows x 9 columns]

# %%
data.head(10)
# Out:
#    Survived   Age  SibSp     Fare      1      Q      S      2      3
# 0       0.0  34.5    0.0   7.8292   True   True  False  False   True
# 1       1.0  47.0    1.0   7.0000  False  False   True  False   True
# 2       0.0  62.0    0.0   9.6875   True   True  False   True  False
# 3       0.0  27.0    0.0   8.6625   True  False   True  False   True
# 4       1.0  22.0    1.0  12.2875  False  False   True  False   True
# 5       0.0  14.0    0.0   9.2250   True  False   True  False   True
# 6       1.0  30.0    0.0   7.6292  False   True  False  False   True
# 7       0.0  26.0    1.0  29.0000   True  False   True   True  False
# 8       1.0  18.0    0.0   7.2292  False  False  False  False   True
# 9       0.0  21.0    2.0  24.1500   True  False   True  False   True

# %%
data["Q"]= data["Q"].replace({"True":1, "False":0})
data["S"]= data["S"].replace({"True":1, "False":0})

# %%
print(data)
# Out:
#      Survived   Age  SibSp     Fare      1      Q      S      2      3
# 0         0.0  34.5    0.0   7.8292   True   True  False  False   True
# 1         1.0  47.0    1.0   7.0000  False  False   True  False   True
# 2         0.0  62.0    0.0   9.6875   True   True  False   True  False
# 3         0.0  27.0    0.0   8.6625   True  False   True  False   True
# 4         1.0  22.0    1.0  12.2875  False  False   True  False   True
# ..        ...   ...    ...      ...    ...    ...    ...    ...    ...
# 408       NaN   NaN    NaN      NaN    NaN   True  False  False   True
# 410       NaN   NaN    NaN      NaN    NaN   True  False  False   True
# 413       NaN   NaN    NaN      NaN    NaN  False   True  False   True
# 416       NaN   NaN    NaN      NaN    NaN  False   True  False   True
# 417       NaN   NaN    NaN      NaN    NaN  False  False  False   True
#
# [418 rows x 9 columns]

# %%
data.head(10)
# Out:
#    Survived   Age  SibSp     Fare      1      Q      S      2      3
# 0       0.0  34.5    0.0   7.8292   True   True  False  False   True
# 1       1.0  47.0    1.0   7.0000  False  False   True  False   True
# 2       0.0  62.0    0.0   9.6875   True   True  False   True  False
# 3       0.0  27.0    0.0   8.6625   True  False   True  False   True
# 4       1.0  22.0    1.0  12.2875  False  False   True  False   True
# 5       0.0  14.0    0.0   9.2250   True  False   True  False   True
# 6       1.0  30.0    0.0   7.6292  False   True  False  False   True
# 7       0.0  26.0    1.0  29.0000   True  False   True   True  False
# 8       1.0  18.0    0.0   7.2292  False  False  False  False   True
# 9       0.0  21.0    2.0  24.1500   True  False   True  False   True

# %%
print(data.dtypes)
# Out:
# Survived    float64
# Age         float64
# SibSp       float64
# Fare        float64
# 1            object
# Q              bool
# S              bool
# 2              bool
# 3              bool
# dtype: object

# %%
data["Q"]= data["Q"].astype(bool)
data["S"]= data["Q"].astype(bool)

data["Q"]= data["Q"].replace({"True":1, "False":0})
data["S"]= data["Q"].replace({"True":1, "False":0})

# %%
data.head(10)
# Out:
#    Survived   Age  SibSp     Fare      1      Q      S      2      3
# 0       0.0  34.5    0.0   7.8292   True   True   True  False   True
# 1       1.0  47.0    1.0   7.0000  False  False  False  False   True
# 2       0.0  62.0    0.0   9.6875   True   True   True   True  False
# 3       0.0  27.0    0.0   8.6625   True  False  False  False   True
# 4       1.0  22.0    1.0  12.2875  False  False  False  False   True
# 5       0.0  14.0    0.0   9.2250   True  False  False  False   True
# 6       1.0  30.0    0.0   7.6292  False   True   True  False   True
# 7       0.0  26.0    1.0  29.0000   True  False  False   True  False
# 8       1.0  18.0    0.0   7.2292  False  False  False  False   True
# 9       0.0  21.0    2.0  24.1500   True  False  False  False   True

# %%
print(data)
# Out:
#      Survived   Age  SibSp     Fare      1      Q      S      2      3
# 0         0.0  34.5    0.0   7.8292   True   True   True  False   True
# 1         1.0  47.0    1.0   7.0000  False  False  False  False   True
# 2         0.0  62.0    0.0   9.6875   True   True   True   True  False
# 3         0.0  27.0    0.0   8.6625   True  False  False  False   True
# 4         1.0  22.0    1.0  12.2875  False  False  False  False   True
# ..        ...   ...    ...      ...    ...    ...    ...    ...    ...
# 408       NaN   NaN    NaN      NaN    NaN   True   True  False   True
# 410       NaN   NaN    NaN      NaN    NaN   True   True  False   True
# 413       NaN   NaN    NaN      NaN    NaN  False  False  False   True
# 416       NaN   NaN    NaN      NaN    NaN  False  False  False   True
# 417       NaN   NaN    NaN      NaN    NaN  False  False  False   True
#
# [418 rows x 9 columns]

# %%
data[1]= data[1].astype(bool)

data[1]= data[1].replace({"True":1, "False":0})
d

# %%
data.head(10)
# Out:
#    Survived   Age  SibSp     Fare      1      Q      S      2      3
# 0       0.0  34.5    0.0   7.8292   True   True   True  False   True
# 1       1.0  47.0    1.0   7.0000  False  False  False  False   True
# 2       0.0  62.0    0.0   9.6875   True   True   True   True  False
# 3       0.0  27.0    0.0   8.6625   True  False  False  False   True
# 4       1.0  22.0    1.0  12.2875  False  False  False  False   True
# 5       0.0  14.0    0.0   9.2250   True  False  False  False   True
# 6       1.0  30.0    0.0   7.6292  False   True   True  False   True
# 7       0.0  26.0    1.0  29.0000   True  False  False   True  False
# 8       1.0  18.0    0.0   7.2292  False  False  False  False   True
# 9       0.0  21.0    2.0  24.1500   True  False  False  False   True

# %%
data[1]= data[1].astype(bool)

data[1]= data[1].replace({True:1, False:0})
data.head(10)
# Out:
#    Survived   Age  SibSp     Fare  1      Q      S      2      3
# 0       0.0  34.5    0.0   7.8292  1   True   True  False   True
# 1       1.0  47.0    1.0   7.0000  0  False  False  False   True
# 2       0.0  62.0    0.0   9.6875  1   True   True   True  False
# 3       0.0  27.0    0.0   8.6625  1  False  False  False   True
# 4       1.0  22.0    1.0  12.2875  0  False  False  False   True
# 5       0.0  14.0    0.0   9.2250  1  False  False  False   True
# 6       1.0  30.0    0.0   7.6292  0   True   True  False   True
# 7       0.0  26.0    1.0  29.0000  1  False  False   True  False
# 8       1.0  18.0    0.0   7.2292  0  False  False  False   True
# 9       0.0  21.0    2.0  24.1500  1  False  False  False   True

# %%
data["Q"]= data["Q"].replace({True:1, False:0})
data["S"]= data["S"].replace({True:1, False:0})
data[2]= data[1].replace({True:1, False:0})
data[3]= data[1].replace({True:1, False:0})
data.head(10)
# Out:
#    Survived   Age  SibSp     Fare  1  Q  S  2  3
# 0       0.0  34.5    0.0   7.8292  1  1  1  1  1
# 1       1.0  47.0    1.0   7.0000  0  0  0  0  0
# 2       0.0  62.0    0.0   9.6875  1  1  1  1  1
# 3       0.0  27.0    0.0   8.6625  1  0  0  1  1
# 4       1.0  22.0    1.0  12.2875  0  0  0  0  0
# 5       0.0  14.0    0.0   9.2250  1  0  0  1  1
# 6       1.0  30.0    0.0   7.6292  0  1  1  0  0
# 7       0.0  26.0    1.0  29.0000  1  0  0  1  1
# 8       1.0  18.0    0.0   7.2292  0  0  0  0  0
# 9       0.0  21.0    2.0  24.1500  1  0  0  1  1

# %%
data.rename(columns={'1':"Male"}, inplace=True)

# %%
data.head(10)
# Out:
#    Survived   Age  SibSp     Fare  1  Q  S  2  3
# 0       0.0  34.5    0.0   7.8292  1  1  1  1  1
# 1       1.0  47.0    1.0   7.0000  0  0  0  0  0
# 2       0.0  62.0    0.0   9.6875  1  1  1  1  1
# 3       0.0  27.0    0.0   8.6625  1  0  0  1  1
# 4       1.0  22.0    1.0  12.2875  0  0  0  0  0
# 5       0.0  14.0    0.0   9.2250  1  0  0  1  1
# 6       1.0  30.0    0.0   7.6292  0  1  1  0  0
# 7       0.0  26.0    1.0  29.0000  1  0  0  1  1
# 8       1.0  18.0    0.0   7.2292  0  0  0  0  0
# 9       0.0  21.0    2.0  24.1500  1  0  0  1  1

# %%
data.rename(columns={1:"Male"}, inplace=True)
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.rename(columns={1:"Male"}, inplace=True)
#       2 data.head(10)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Training Data

# %%
x=data.drop("Survived",axis=1)
y=data["Survived"]

# %%
from sklearn.cross_validation import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from sklearn.cross_validation import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn.cross_validation'

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=1)
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 logmodel.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
# Out:
#   Cell In[2], line 1
#     for(i==0,j==10;i<j;i++,j--)
#                   ^
# SyntaxError: invalid syntax

# %%
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.head(10)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
data= pd.read_csv('D:tested.csv')
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
# ----> 5 data= pd.read_csv('D:tested.csv')
#       6 data.head(10)
#
# ...

# %%
spam_amount = 0
viking_song = "Spam " * spam_amount
print(viking_song)
